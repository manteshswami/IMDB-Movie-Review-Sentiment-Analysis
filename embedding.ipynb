# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[4795, 4691, 1943, 3751],
#  [4795, 4691, 1943, 8181],
#  [4795, 9864, 1943, 4355],
#  [9222, 7112, 1544, 2584, 8765],
#  [9222, 7112, 1544, 2584, 7070],
#  [5699, 4795, 2496, 1943, 4167],
#  [2853, 3970, 2707, 2584]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
#from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 4795 4691 1943 3751]
#  [   0    0    0    0 4795 4691 1943 8181]
#  [   0    0    0    0 4795 9864 1943 4355]
#  [   0    0    0 9222 7112 1544 2584 8765]
#  [   0    0    0 9222 7112 1544 2584 7070]
#  [   0    0    0 5699 4795 2496 1943 4167]
#  [   0    0    0    0 2853 3970 2707 2584]]

# %%
## feature representation
dim=10

# %%
model=Sequential()

model.add(Embedding(voc_size,dim,input_length=sent_length))
model.build(input_shape=(None,sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# array([[[-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [ 0.03618368, -0.01325859, -0.0391075 , -0.03810734,
#          -0.01340293, -0.01146353,  0.00881436, -0.01640088,
#           0.03262449, -0.01607735],
#         [-0.03088078, -0.04674672, -0.04389639,  0.03689054,
#          -0.04001421,  0.03424374,  0.00710324, -0.01237289,
#          -0.01661047,  0.02544249],
#         [ 0.02519231,  0.04726053, -0.04395846,  0.04453245,
#           0.04823602, -0.01839446, -0.01845841, -0.04266944,
#           0.04794656,  0.00441489],
#         [-0.00618947,  0.04076334, -0.01842407,  0.02539212,
#          -0.04635396, -0.04834156,  0.0277292 , -0.02494185,
#          -0.0181002 ,  0.03080526]],
#
#        [[-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [ 0.03618368, -0.01325859, -0.0391075 , -0.03810734,
#          -0.01340293, -0.01146353,  0.00881436, -0.01640088,
#           0.03262449, -0.01607735],
#         [-0.03088078, -0.04674672, -0.04389639,  0.03689054,
#          -0.04001421,  0.03424374,  0.00710324, -0.01237289,
#          -0.01661047,  0.02544249],
#         [ 0.02519231,  0.04726053, -0.04395846,  0.04453245,
#           0.04823602, -0.01839446, -0.01845841, -0.04266944,
#           0.04794656,  0.00441489],
#         [ 0.00538421,  0.04584484, -0.03473448, -0.04485173,
#           0.03393454,  0.04633417,  0.02209948,  0.03147889,
#          -0.04575348,  0.04363891]],
#
#        [[-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [ 0.03618368, -0.01325859, -0.0391075 , -0.03810734,
#          -0.01340293, -0.01146353,  0.00881436, -0.01640088,
#           0.03262449, -0.01607735],
#         [ 0.03463972,  0.02359021,  0.01131443,  0.04204461,
#          -0.03287393,  0.00902135, -0.02787828,  0.03870228,
#           0.00897591, -0.03097853],
#         [ 0.02519231,  0.04726053, -0.04395846,  0.04453245,
#           0.04823602, -0.01839446, -0.01845841, -0.04266944,
#           0.04794656,  0.00441489],
#         [ 0.01039373,  0.04686632, -0.02330502,  0.00300745,
#           0.0404242 ,  0.02728946, -0.04984063, -0.02579699,
#           0.011386  ,  0.00686488]],
#
#        [[-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04636747,  0.01649672,  0.04372909, -0.03632893,
#          -0.01108177,  0.02982249,  0.04750122,  0.00273727,
#           0.01508411,  0.0057301 ],
#         [ 0.0420466 , -0.02372648,  0.00713208,  0.03980363,
#          -0.00345946,  0.03457935,  0.01962597,  0.02555568,
#           0.04563097,  0.00865458],
#         [-0.01139147,  0.01047442, -0.02117276,  0.03234566,
#          -0.02357631,  0.04089847,  0.04727229, -0.04902663,
#          -0.02558249,  0.02410528],
#         [ 0.04020444, -0.02430061,  0.04713693, -0.04139565,
#           0.02817085,  0.01142522, -0.02251942, -0.02428341,
#           0.01975502, -0.03893497],
#         [ 0.00795808,  0.03384912, -0.02641878,  0.00599102,
#           0.0047297 ,  0.00996419, -0.01720191,  0.04688454,
#           0.0288868 ,  0.03449676]],
#
#        [[-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04636747,  0.01649672,  0.04372909, -0.03632893,
#          -0.01108177,  0.02982249,  0.04750122,  0.00273727,
#           0.01508411,  0.0057301 ],
#         [ 0.0420466 , -0.02372648,  0.00713208,  0.03980363,
#          -0.00345946,  0.03457935,  0.01962597,  0.02555568,
#           0.04563097,  0.00865458],
#         [-0.01139147,  0.01047442, -0.02117276,  0.03234566,
#          -0.02357631,  0.04089847,  0.04727229, -0.04902663,
#          -0.02558249,  0.02410528],
#         [ 0.04020444, -0.02430061,  0.04713693, -0.04139565,
#           0.02817085,  0.01142522, -0.02251942, -0.02428341,
#           0.01975502, -0.03893497],
#         [ 0.04490454,  0.03710615, -0.00044203,  0.03891117,
#          -0.00983182,  0.04986718, -0.04189075,  0.02864188,
#           0.02603838,  0.03955806]],
#
#        [[-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.03740288, -0.02714323, -0.00633391,  0.04496166,
#          -0.03770691, -0.04534331,  0.03976157,  0.04625275,
#           0.04255328,  0.01353315],
#         [ 0.03618368, -0.01325859, -0.0391075 , -0.03810734,
#          -0.01340293, -0.01146353,  0.00881436, -0.01640088,
#           0.03262449, -0.01607735],
#         [ 0.03485228, -0.04965452,  0.00600412, -0.04920423,
#          -0.01900277,  0.00473254,  0.01342976, -0.02720335,
#          -0.01384823,  0.03880873],
#         [ 0.02519231,  0.04726053, -0.04395846,  0.04453245,
#           0.04823602, -0.01839446, -0.01845841, -0.04266944,
#           0.04794656,  0.00441489],
#         [ 0.02521821, -0.02762815,  0.02182185, -0.01575184,
#          -0.0059106 ,  0.01567758, -0.01488753, -0.04854559,
#           0.03355758,  0.00660457]],
#
#        [[-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [-0.04177197,  0.02715454, -0.00142074, -0.00190531,
#           0.01361691,  0.00331607,  0.02283729, -0.02584249,
#           0.04720249,  0.04193124],
#         [ 0.04483744, -0.0209251 , -0.04431698,  0.01728335,
#          -0.02486751, -0.01125211,  0.02514614,  0.04237166,
#          -0.0416433 ,  0.01906106],
#         [-0.04320475,  0.01576335, -0.04049901,  0.04577726,
#           0.01618801, -0.04108065,  0.02328226, -0.03623067,
#          -0.03871187,  0.04334755],
#         [-0.03955738,  0.04148152,  0.04037656,  0.04992353,
#           0.00443172,  0.00297425,  0.04554555, -0.0427327 ,
#          -0.02591685,  0.00589762],
#         [ 0.04020444, -0.02430061,  0.04713693, -0.04139565,
#           0.02817085,  0.01142522, -0.02251942, -0.02428341,
#           0.01975502, -0.03893497]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 4795, 4691, 1943, 3751])
